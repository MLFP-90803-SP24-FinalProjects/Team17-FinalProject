# %% [markdown]
# # Mortgage Data Cleaning
# ## 90-803 Machine Learning Foundations with Python (Spring 2024)
# ### Team 17: Yoko, Tessa, Hannah

# %%
import pandas as pd
import matplotlib as plot
import seaborn as sns

# %%
# Reading excel data
mortgages = pd.read_excel("Table26-2019-by-Month.xls")
# mortgages.dropna(inplace=True)
# mortgages.rename(columns=mortgages.iloc[0], inplace=True)
# mortgages.drop(index=(5), inplace=True)
# mortgages.reset_index(inplace=True)
# mortgages.drop(columns=['index','Contract Interest Rate (%)'],inplace=True)
# mortgages.to_csv("mortgage_rates.csv")
mortgages.head(25)
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3   TABLE 26: TERMS ON CONVENTIONAL SINGLE FAMILY ...        NaN
# 4                                                 NaN        NaN
# 5                                                Year      Month
# 6                                                1990          1
# 7                                                1990          2
# 8                                                1990          3
# 9                                                1990          4
# 10                                               1990          5
# 11                                               1990          6
# 12                                               1990          7
# ...

# %%
# Visualize over time
sns.lineplot(data=mortgages, x='Year', y='Effective Rate (%)').set_title("Effective Mortgage Rate over Time")
# Out:
# Text(0.5, 1.0, 'Effective Mortgage Rate over Time')

# %%
# Visualize over time
sns.lineplot(data=mortgages, x='Year', y='Initial Fees and Charges (%)').set_title("Initial Fees and Charges over time")
# Out:
# Text(0.5, 1.0, 'Initial Fees and Charges over time')

# %%
# Visualize over time
sns.lineplot(data=mortgages, x='Year', y='Share of Total Market (%)')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Share of Total Market (%)'>

# %%
# Visualize over time
sns.lineplot(data=mortgages, x='Year', y='Loan-to-Price Ratio (%)').set_title("Loan-to-Price Ratio over time")
# Out:
# Text(0.5, 1.0, 'Loan-to-Price Ratio over time')

# %%
# Visualize over time
sns.lineplot(data=mortgages, x='Year', y='Purchase Price ($thou)').set_title("Purchase Price over time")
# Out:
# Text(0.5, 1.0, 'Purchase Price over time')

# %% [markdown]
# ### References
#
# 1. https://seaborn.pydata.org/generated/seaborn.lineplot.html
# 2. https://www.fhfa.gov/DataTools/Downloads/Pages/Monthly-Interest-Rate-Data.aspx
