# %% [markdown]
# # Modeling Climate and Housing Data: Regression

# %% [markdown]
# We are attempting to predict home values (or purchase prices) based on climate indicators, so in this file we are exploring the following:
# * Linear Regression
# * Polynomial Regressions
# * Feature selection
#
# This file should answer the following question:
# Can we predict real estate purchase price based on climate indicators?

# %%
# importing relevant libraries
from datetime import datetime
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import geopandas as gpd
# %matplotlib inline

# Importing metrics for model evaluation
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.metrics import recall_score, precision_score, accuracy_score
from sklearn.model_selection import train_test_split, LeaveOneOut, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV 
from sklearn.feature_selection import SequentialFeatureSelector

# Importing class balance tools for handling imbalanced datasets
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from yellowbrick.target import ClassBalance

# Importing classifier models
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ## Read the data and look at it

# %%
data = pd.read_csv("all_data.csv", index_col=0)
data.head()
# Out:
#          Date  Year  Month          RegionName State  \
# 0  2000-01-31  2000      1  Los Angeles County    CA
# 1  2000-01-31  2000      1  Los Angeles County    CA
# 2  2000-01-31  2000      1         Cook County    IL
# 3  2000-01-31  2000      1         Cook County    IL
# 4  2000-01-31  2000      1       Harris County    TX
#
#    Bottom-Tier Average Home Value Estimate  \
# 0                            122826.545216
# 1                            122826.545216
# 2                             71689.188026
# 3                             71689.188026
# 4                             61195.175569
#
#    Top-Tier Average Home Value Estimate  Value  \
# 0                         400192.738911   52.3
# 1                         400192.738911   52.3
# 2                         302264.545103   24.9
# 3                         302264.545103   24.9
# 4                         217850.462915   57.4
#
#    Anomaly (1901-2000 base period)  1901-2000 Mean StateAbbrv  \
# 0                              4.5            47.8         CA
# 1                              4.5            47.8         CA
# 2                              2.4            22.5         IL
# 3                              2.4            22.5         IL
# 4                              5.6            51.8         TX
#
#    Initial Fees and Charges (%)  Effective Rate (%)  Term to Maturity  \
# 0                          0.93                8.01                15
# 1                          0.81                8.20                30
# 2                          0.93                8.01                15
# 3                          0.81                8.20                30
# 4                          0.93                8.01                15
#
#    Loan Amount ($thou)  Purchase Price ($thou)  Loan-to-Price Ratio (%)  \
# 0                103.0                   173.6                     64.7
# 1                129.9                   166.8                     81.1
# 2                103.0                   173.6                     64.7
# 3                129.9                   166.8                     81.1
# 4                103.0                   173.6                     64.7
#
#    Share of Total Market (%)
# 0                        7.0
# 1                       61.1
# 2                        7.0
# 3                       61.1
# 4                        7.0

# %%
data.drop(columns=['Date'], inplace=True)
data.rename(columns={'Value': 'Average Temperature Value'}, inplace=True)

# %% [markdown]
# ## Read in Geo-data
# We want to relate this data to where the counties exist in geospatial relation to one another, so we are going to read county longitude and latitude data and merge it.

# %%
# Loading the shapefile in order to visualize clean data on the US map
us_counties = gpd.read_file('tl_2022_us_county/tl_2022_us_county.shp')
print(us_counties.columns)
us_counties.head()
# Out:
# Index(['STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',
#        'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT', 'ALAND',
#        'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')
#   STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD CLASSFP  \
# 0      31      039  00835841  31039     Cuming     Cuming County   06      H1
# 1      53      069  01513275  53069  Wahkiakum  Wahkiakum County   06      H1
# 2      35      011  00933054  35011    De Baca    De Baca County   06      H1
# 3      31      109  00835876  31109  Lancaster  Lancaster County   06      H1
# 4      31      129  00835886  31129   Nuckolls   Nuckolls County   06      H1
#
#    MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 0  G4020  None   None     None        A  1477644346  10691216  +41.9158651
# 1  G4020  None   None     None        A   680980770  61564427  +46.2946377
# 2  G4020  None   None     None        A  6016818946  29090018  +34.3592729
# 3  G4020  None   None     None        A  2169272978  22847034  +40.7835474
# 4  G4020  None   None     None        A  1489645185   1718484  +40.1764918
#
#        INTPTLON                                           geometry
# 0  -096.7885168  POLYGON ((-96.55515 41.91587, -96.55515 41.914...
# 1  -123.4244583  POLYGON ((-123.72755 46.26449, -123.72755 46.2...
# 2  -104.3686961  POLYGON ((-104.89337 34.08894, -104.89337 34.0...
# 3  -096.6886584  POLYGON ((-96.68493 40.52330, -96.69219 40.523...
# 4  -098.0468422  POLYGON ((-98.27370 40.11840, -98.27374 40.122...

# %%
# Merge the geospatial United States map with the data
data = data.merge(us_counties, left_on='RegionName', right_on='NAMELSAD')

data.head()
# Out:
#    Year  Month          RegionName State  \
# 0  2000      1  Los Angeles County    CA
# 1  2000      1  Los Angeles County    CA
# 2  2000      1         Cook County    IL
# 3  2000      1         Cook County    IL
# 4  2000      1         Cook County    IL
#
#    Bottom-Tier Average Home Value Estimate  \
# 0                            122826.545216
# 1                            122826.545216
# 2                             71689.188026
# 3                             71689.188026
# 4                             71689.188026
#
#    Top-Tier Average Home Value Estimate  Average Temperature Value  \
# 0                         400192.738911                       52.3
# 1                         400192.738911                       52.3
# 2                         302264.545103                       24.9
# 3                         302264.545103                       24.9
# 4                         302264.545103                       24.9
#
#    Anomaly (1901-2000 base period)  1901-2000 Mean StateAbbrv  ...  MTFCC  \
# 0                              4.5            47.8         CA  ...  G4020
# 1                              4.5            47.8         CA  ...  G4020
# 2                              2.4            22.5         IL  ...  G4020
# 3                              2.4            22.5         IL  ...  G4020
# 4                              2.4            22.5         IL  ...  G4020
#
#    CSAFP  CBSAFP  METDIVFP  FUNCSTAT        ALAND      AWATER     INTPTLAT  \
# 0   None    None      None         A  10515988166  1785003207  +34.1963983
# 1   None    None      None         A  10515988166  1785003207  +34.1963983
# 2   None    None      None         A    591684404    12308449  +31.1525157
# 3   None    None      None         A   2447342616  1786339408  +41.8942937
# 4   None    None      None         A   3762130687  4887924296  +47.7585562
#
#        INTPTLON                                           geometry
# 0  -118.2618616  MULTIPOLYGON (((-118.67820 33.03973, -118.6756...
# 1  -118.2618616  MULTIPOLYGON (((-118.67820 33.03973, -118.6756...
# 2  -083.4294448  POLYGON ((-83.51530 31.30235, -83.51487 31.302...
# 3  -087.6454546  POLYGON ((-87.52500 41.64464, -87.52505 41.639...
# 4  -090.3443192  POLYGON ((-90.75158 48.09099, -90.74146 48.094...
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Look for multicollinearity
#
# We suspect that housing values may simply change over time due to factors not listed in our dataset, which would make the Year (and possibly the Month) column heavily collinear. As we see below, it does have high collinearity with some features. We will proceed, anyway, but we will keep this in mind.

# %%
data.drop(columns=['RegionName', 'State', 'StateAbbrv', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).corr()
# Out:
#                                                  Year         Month  \
# Year                                     1.000000e+00 -4.635286e-02
# Month                                   -4.635286e-02  1.000000e+00
# Bottom-Tier Average Home Value Estimate  1.385478e-01  2.378904e-03
# Top-Tier Average Home Value Estimate     9.028155e-02  3.252821e-03
# Average Temperature Value               -2.328454e-02  2.318414e-01
# Anomaly (1901-2000 base period)          7.537731e-02  6.370853e-03
# 1901-2000 Mean                          -3.866954e-02  2.308733e-01
# Initial Fees and Charges (%)             8.401242e-01  1.671322e-02
# Effective Rate (%)                      -8.376533e-01 -1.961462e-02
# Term to Maturity                        -3.391730e-14  1.076551e-15
# Loan Amount ($thou)                      7.313545e-01  8.994433e-03
# Purchase Price ($thou)                   7.612476e-01  6.646821e-04
# Loan-to-Price Ratio (%)                  2.919135e-01  1.073798e-02
# Share of Total Market (%)                1.517370e-03  1.855096e-03
# ALAND                                    2.260147e-03 -2.575444e-04
# AWATER                                  -1.031388e-02  3.192193e-04
# INTPTLAT                                 2.227470e-03  4.691290e-05
# INTPTLON                                -2.014182e-02  1.915278e-05
#
#                                          Bottom-Tier Average Home Value Estimate  \
# Year                                                                1.385478e-01
# Month                                                               2.378904e-03
# Bottom-Tier Average Home Value Estimate                             1.000000e+00
# Top-Tier Average Home Value Estimate                                8.416110e-01
# Average Temperature Value                                          -7.520899e-02
# Anomaly (1901-2000 base period)                                     7.200212e-02
# 1901-2000 Mean                                                     -8.998843e-02
# Initial Fees and Charges (%)                                        6.676287e-02
# Effective Rate (%)                                                 -6.662231e-02
# Term to Maturity                                                   -1.931882e-15
# Loan Amount ($thou)                                                 1.249402e-01
# Purchase Price ($thou)                                              1.597593e-01
# Loan-to-Price Ratio (%)                                             2.727633e-02
# Share of Total Market (%)                                          -1.459481e-03
# ALAND                                                               5.269749e-02
# AWATER                                                              4.958064e-02
# INTPTLAT                                                            5.600114e-02
# INTPTLON                                                           -5.441112e-02
#
#                                          Top-Tier Average Home Value Estimate  \
# Year                                                             9.028155e-02
# Month                                                            3.252821e-03
# Bottom-Tier Average Home Value Estimate                          8.416110e-01
# Top-Tier Average Home Value Estimate                             1.000000e+00
# Average Temperature Value                                       -4.430663e-02
# Anomaly (1901-2000 base period)                                  5.367777e-02
# 1901-2000 Mean                                                  -5.530837e-02
# Initial Fees and Charges (%)                                     2.904173e-02
# Effective Rate (%)                                              -4.126861e-02
# Term to Maturity                                                -1.217581e-16
# Loan Amount ($thou)                                              8.581774e-02
# Purchase Price ($thou)                                           1.157574e-01
# Loan-to-Price Ratio (%)                                          1.671263e-02
# Share of Total Market (%)                                       -1.928182e-03
# ALAND                                                            4.920400e-02
# AWATER                                                           6.093294e-02
# INTPTLAT                                                         3.938012e-02
# INTPTLON                                                        -5.542544e-02
#
#                                          Average Temperature Value  \
# Year                                                 -2.328454e-02
# Month                                                 2.318414e-01
# Bottom-Tier Average Home Value Estimate              -7.520899e-02
# Top-Tier Average Home Value Estimate                 -4.430663e-02
# Average Temperature Value                             1.000000e+00
# Anomaly (1901-2000 base period)                       1.086192e-01
# 1901-2000 Mean                                        9.792791e-01
# Initial Fees and Charges (%)                          6.518566e-03
# Effective Rate (%)                                    8.636151e-03
# Term to Maturity                                     -1.841740e-16
# Loan Amount ($thou)                                   8.913638e-03
# Purchase Price ($thou)                                8.491858e-03
# Loan-to-Price Ratio (%)                               2.910845e-03
# Share of Total Market (%)                            -1.077079e-02
# ALAND                                                -1.086584e-02
# AWATER                                               -6.711149e-03
# INTPTLAT                                             -1.159709e-01
# INTPTLON                                              1.527432e-02
#
#                                          Anomaly (1901-2000 base period)  \
# Year                                                        7.537731e-02
# Month                                                       6.370853e-03
# Bottom-Tier Average Home Value Estimate                     7.200212e-02
# Top-Tier Average Home Value Estimate                        5.367777e-02
# Average Temperature Value                                   1.086192e-01
# Anomaly (1901-2000 base period)                             1.000000e+00
# 1901-2000 Mean                                             -9.494819e-02
# Initial Fees and Charges (%)                                9.926570e-02
# Effective Rate (%)                                         -6.492020e-02
# Term to Maturity                                           -3.068261e-15
# Loan Amount ($thou)                                         2.993734e-02
# Purchase Price ($thou)                                      3.157528e-02
# Loan-to-Price Ratio (%)                                     1.449052e-02
# Share of Total Market (%)                                  -1.545033e-02
# ALAND                                                       9.605814e-03
# AWATER                                                      1.022556e-02
# INTPTLAT                                                    1.305892e-02
# INTPTLON                                                    5.125142e-03
#
#                                          1901-2000 Mean  \
# Year                                      -3.866954e-02
# Month                                      2.308733e-01
# Bottom-Tier Average Home Value Estimate   -8.998843e-02
# Top-Tier Average Home Value Estimate      -5.530837e-02
# Average Temperature Value                  9.792791e-01
# Anomaly (1901-2000 base period)           -9.494819e-02
# 1901-2000 Mean                             1.000000e+00
# Initial Fees and Charges (%)              -1.369151e-02
# Effective Rate (%)                         2.187059e-02
# Term to Maturity                           4.407788e-16
# Loan Amount ($thou)                        2.829632e-03
# Purchase Price ($thou)                     2.073569e-03
# Loan-to-Price Ratio (%)                   -3.577331e-05
# Share of Total Market (%)                 -7.638376e-03
# ALAND                                     -1.283784e-02
# AWATER                                    -8.802131e-03
# INTPTLAT                                  -1.187941e-01
# INTPTLON                                   1.425320e-02
#
#                                          Initial Fees and Charges (%)  \
# Year                                                         0.840124
# Month                                                        0.016713
# Bottom-Tier Average Home Value Estimate                      0.066763
# Top-Tier Average Home Value Estimate                         0.029042
# Average Temperature Value                                    0.006519
# Anomaly (1901-2000 base period)                              0.099266
# 1901-2000 Mean                                              -0.013692
# Initial Fees and Charges (%)                                 1.000000
# Effective Rate (%)                                          -0.683005
# Term to Maturity                                             0.135594
# Loan Amount ($thou)                                          0.661910
# Purchase Price ($thou)                                       0.533555
# Loan-to-Price Ratio (%)                                      0.398774
# Share of Total Market (%)                                    0.115981
# ALAND                                                        0.002088
# AWATER                                                      -0.010346
# INTPTLAT                                                     0.000925
# INTPTLON                                                    -0.016529
#
#                                          Effective Rate (%)  Term to Maturity  \
# Year                                              -0.837653     -3.391730e-14
# Month                                             -0.019615      1.076551e-15
# Bottom-Tier Average Home Value Estimate           -0.066622     -1.931882e-15
# Top-Tier Average Home Value Estimate              -0.041269     -1.217581e-16
# Average Temperature Value                          0.008636     -1.841740e-16
# Anomaly (1901-2000 base period)                   -0.064920     -3.068261e-15
# 1901-2000 Mean                                     0.021871      4.407788e-16
# Initial Fees and Charges (%)                      -0.683005      1.355944e-01
# Effective Rate (%)                                 1.000000      1.907197e-01
# Term to Maturity                                   0.190720      1.000000e+00
# Loan Amount ($thou)                               -0.500023      5.832566e-01
# Purchase Price ($thou)                            -0.637850     -3.423844e-02
# Loan-to-Price Ratio (%)                           -0.112535      8.555960e-01
# Share of Total Market (%)                          0.187445      9.855307e-01
# ALAND                                             -0.001939     -1.030285e-16
# AWATER                                             0.009879      4.708983e-16
# INTPTLAT                                          -0.002585      2.670650e-17
# INTPTLON                                           0.019042      6.472562e-16
#
#                                          Loan Amount ($thou)  \
# Year                                                0.731354
# Month                                               0.008994
# Bottom-Tier Average Home Value Estimate             0.124940
# Top-Tier Average Home Value Estimate                0.085818
# Average Temperature Value                           0.008914
# Anomaly (1901-2000 base period)                     0.029937
# 1901-2000 Mean                                      0.002830
# Initial Fees and Charges (%)                        0.661910
# Effective Rate (%)                                 -0.500023
# Term to Maturity                                    0.583257
# Loan Amount ($thou)                                 1.000000
# Purchase Price ($thou)                              0.728694
# Loan-to-Price Ratio (%)                             0.720618
# Share of Total Market (%)                           0.579628
# ALAND                                               0.001416
# AWATER                                             -0.007160
# INTPTLAT                                            0.001327
# INTPTLON                                           -0.013871
#
#                                          Purchase Price ($thou)  \
# Year                                                   0.761248
# Month                                                  0.000665
# Bottom-Tier Average Home Value Estimate                0.159759
# Top-Tier Average Home Value Estimate                   0.115757
# Average Temperature Value                              0.008492
# Anomaly (1901-2000 base period)                        0.031575
# 1901-2000 Mean                                         0.002074
# Initial Fees and Charges (%)                           0.533555
# Effective Rate (%)                                    -0.637850
# Term to Maturity                                      -0.034238
# Loan Amount ($thou)                                    0.728694
# Purchase Price ($thou)                                 1.000000
# Loan-to-Price Ratio (%)                                0.081776
# Share of Total Market (%)                             -0.024221
# ALAND                                                  0.001231
# AWATER                                                -0.006729
# INTPTLAT                                               0.001424
# INTPTLON                                              -0.013856
#
#                                          Loan-to-Price Ratio (%)  \
# Year                                                    0.291914
# Month                                                   0.010738
# Bottom-Tier Average Home Value Estimate                 0.027276
# Top-Tier Average Home Value Estimate                    0.016713
# Average Temperature Value                               0.002911
# Anomaly (1901-2000 base period)                         0.014491
# 1901-2000 Mean                                         -0.000036
# Initial Fees and Charges (%)                            0.398774
# Effective Rate (%)                                     -0.112535
# Term to Maturity                                        0.855596
# Loan Amount ($thou)                                     0.720618
# Purchase Price ($thou)                                  0.081776
# Loan-to-Price Ratio (%)                                 1.000000
# Share of Total Market (%)                               0.830704
# ALAND                                                   0.000548
# AWATER                                                 -0.003167
# INTPTLAT                                                0.000663
# INTPTLON                                               -0.006082
#
#                                          Share of Total Market (%)  \
# Year                                                      0.001517
# Month                                                     0.001855
# Bottom-Tier Average Home Value Estimate                  -0.001459
# Top-Tier Average Home Value Estimate                     -0.001928
# Average Temperature Value                                -0.010771
# Anomaly (1901-2000 base period)                          -0.015450
# 1901-2000 Mean                                           -0.007638
# Initial Fees and Charges (%)                              0.115981
# Effective Rate (%)                                        0.187445
# Term to Maturity                                          0.985531
# Loan Amount ($thou)                                       0.579628
# Purchase Price ($thou)                                   -0.024221
# Loan-to-Price Ratio (%)                                   0.830704
# Share of Total Market (%)                                 1.000000
# ALAND                                                     0.000137
# AWATER                                                   -0.000033
# INTPTLAT                                                  0.000131
# INTPTLON                                                 -0.000211
#
#                                                 ALAND        AWATER  \
# Year                                     2.260147e-03 -1.031388e-02
# Month                                   -2.575444e-04  3.192193e-04
# Bottom-Tier Average Home Value Estimate  5.269749e-02  4.958064e-02
# Top-Tier Average Home Value Estimate     4.920400e-02  6.093294e-02
# Average Temperature Value               -1.086584e-02 -6.711149e-03
# Anomaly (1901-2000 base period)          9.605814e-03  1.022556e-02
# 1901-2000 Mean                          -1.283784e-02 -8.802131e-03
# Initial Fees and Charges (%)             2.087636e-03 -1.034586e-02
# Effective Rate (%)                      -1.938852e-03  9.878846e-03
# Term to Maturity                        -1.030285e-16  4.708983e-16
# Loan Amount ($thou)                      1.416196e-03 -7.159737e-03
# Purchase Price ($thou)                   1.230614e-03 -6.729343e-03
# Loan-to-Price Ratio (%)                  5.476009e-04 -3.167368e-03
# Share of Total Market (%)                1.373464e-04 -3.304410e-05
# ALAND                                    1.000000e+00  7.380077e-02
# AWATER                                   7.380077e-02  1.000000e+00
# INTPTLAT                                 1.332584e-01 -1.067738e-02
# INTPTLON                                -4.496183e-01  6.574068e-02
#
#                                              INTPTLAT      INTPTLON
# Year                                     2.227470e-03 -2.014182e-02
# Month                                    4.691290e-05  1.915278e-05
# Bottom-Tier Average Home Value Estimate  5.600114e-02 -5.441112e-02
# Top-Tier Average Home Value Estimate     3.938012e-02 -5.542544e-02
# Average Temperature Value               -1.159709e-01  1.527432e-02
# Anomaly (1901-2000 base period)          1.305892e-02  5.125142e-03
# 1901-2000 Mean                          -1.187941e-01  1.425320e-02
# Initial Fees and Charges (%)             9.253831e-04 -1.652910e-02
# Effective Rate (%)                      -2.585495e-03  1.904187e-02
# Term to Maturity                         2.670650e-17  6.472562e-16
# Loan Amount ($thou)                      1.327262e-03 -1.387067e-02
# Purchase Price ($thou)                   1.423814e-03 -1.385583e-02
# Loan-to-Price Ratio (%)                  6.632654e-04 -6.082496e-03
# Share of Total Market (%)                1.309506e-04 -2.112232e-04
# ALAND                                    1.332584e-01 -4.496183e-01
# AWATER                                  -1.067738e-02  6.574068e-02
# INTPTLAT                                 1.000000e+00 -2.153321e-01
# INTPTLON                                -2.153321e-01  1.000000e+00

# %%
sns.heatmap(data=data.drop(columns=['RegionName', 'State', 'StateAbbrv', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Split the data
# Because this data is origianlly time series, we have broken the year and month into their own columns and dropped the date. Next, we are going to use the latest year as the "test" dataset and all previous years as training.

# %%
test = data[data['Year'] == 2019].copy()
train = data[data['Year'] != 2019].copy()
y_test = test['Purchase Price ($thou)'].copy()
y_train = train['Purchase Price ($thou)'].copy()
X_train = train.drop(columns=['RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()
X_test = test.drop(columns=['RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()

# %%
X_train.columns
# Out:
# Index(['Year', 'Month', 'Bottom-Tier Average Home Value Estimate',
#        'Top-Tier Average Home Value Estimate', 'Average Temperature Value',
#        'Anomaly (1901-2000 base period)', '1901-2000 Mean',
#        'Initial Fees and Charges (%)', 'Effective Rate (%)',
#        'Term to Maturity', 'Loan Amount ($thou)', 'Loan-to-Price Ratio (%)',
#        'Share of Total Market (%)', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON'],
#       dtype='object')

# %% [markdown]
# ## Train a Linear Regression Model

# %%
# your code here
l_model = LinearRegression()
l_model.fit(X_train, y_train)
y_pred_test = l_model.predict(X_test)
y_pred_train = l_model.predict(X_train)

r_squared_train_linear = r2_score(y_train, y_pred_train)
r_squared_test_linear = r2_score(y_test, y_pred_test)

mean_squared_error_train_linear = mean_squared_error(y_train, y_pred_train)
mean_squared_error_test_linear = mean_squared_error(y_test, y_pred_test)

# Printing results for training
print('r_squared_train:', round(r_squared_train_linear, 3))
print('mean_squared_error_train:', round(mean_squared_error_train_linear, 3))

# Printing results for testing
print('r_squared_test:',round(r_squared_test_linear, 3))
print('mean_squared_error_test:',round(mean_squared_error_test_linear, 3))
# Out:
# r_squared_train: 0.964
# mean_squared_error_train: 46.617
# r_squared_test: 0.551
# mean_squared_error_test: 44.389

# %% [markdown]
# The training data did incredibly well where the test data did just OK. The MSE values for both are decently low but there is a mismatch with R2 values. This seems suspicious -- I think it may be due to the Year column.
#
# I am going to check which features are most important below.
#
# ## Feature Selection

# %%
for i in range(1,5):
    sfs = SequentialFeatureSelector(estimator=LinearRegression(),
                              n_features_to_select=i,
                              direction = 'forward',
                              scoring = 'neg_mean_squared_error')
    sfs = sfs.fit(X_train, y_train)

    feature_names = np.array(X_train.columns)
    selected_feature_names = feature_names[sfs.get_support()].tolist()
    print("Selected features:", selected_feature_names)
# Out:
# Selected features: ['Year']
# Selected features: ['Year', 'Loan-to-Price Ratio (%)']
# Selected features: ['Year', 'Loan Amount ($thou)', 'Loan-to-Price Ratio (%)']
# Selected features: ['Year', 'Loan Amount ($thou)', 'Loan-to-Price Ratio (%)', 'Share of Total Market (%)']

# %% [markdown]
# As I suspected, Year is the most important, almost certainly due to factors not in this dataset.
#
# Next, I am going to drop the Year column and see what happens.

# %%
# Try again without "Year" data because it seems too strongly correlated and we are trying to do this based on climate data...
test = data[data['Year'] == 2019].copy()
train = data[data['Year'] != 2019].copy()
y_test = test['Purchase Price ($thou)'].copy()
y_train = train['Purchase Price ($thou)'].copy()
X_train = train.drop(columns=['Year', 'RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()
X_test = test.drop(columns=['Year', 'RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()

# %%
# your code here
l_model = LinearRegression()
l_model.fit(X_train, y_train)
y_pred_test = l_model.predict(X_test)
y_pred_train = l_model.predict(X_train)

r_squared_train_linear = r2_score(y_train, y_pred_train)
r_squared_test_linear = r2_score(y_test, y_pred_test)

mean_squared_error_train_linear = mean_squared_error(y_train, y_pred_train)
mean_squared_error_test_linear = mean_squared_error(y_test, y_pred_test)

# Printing results for training
print('r_squared_train:', round(r_squared_train_linear, 3))
print('mean_squared_error_train:', round(mean_squared_error_train_linear, 3))

# Printing results for testing
print('r_squared_test:',round(r_squared_test_linear, 3))
print('mean_squared_error_test:',round(mean_squared_error_test_linear, 3))
# Out:
# r_squared_train: 0.963
# mean_squared_error_train: 48.567
# r_squared_test: 0.31
# mean_squared_error_test: 68.302

# %% [markdown]
# Already, we see the R2 for the test dataset go down to 0.31. The Year was a big feature. I want to also try dropping some of those other features that are not related to climate. I will drop 'Loan-to-Price Ratio (%)'.

# %%
# Try again without "Year" data because it seems too strongly correlated and we are trying to do this based on climate data...
test = data[data['Year'] == 2019].copy()
train = data[data['Year'] != 2019].copy()
y_test = test['Purchase Price ($thou)'].copy()
y_train = train['Purchase Price ($thou)'].copy()
X_train = train.drop(columns=['Year', 'Loan-to-Price Ratio (%)', 'RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()
X_test = test.drop(columns=['Year', 'RegionName', 'Loan-to-Price Ratio (%)', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()

# %%
# your code here
l_model = LinearRegression()
l_model.fit(X_train, y_train)
y_pred_test = l_model.predict(X_test)
y_pred_train = l_model.predict(X_train)

r_squared_train_linear = r2_score(y_train, y_pred_train)
r_squared_test_linear = r2_score(y_test, y_pred_test)

mean_squared_error_train_linear = mean_squared_error(y_train, y_pred_train)
mean_squared_error_test_linear = mean_squared_error(y_test, y_pred_test)

# Printing results for training
print('r_squared_train:', round(r_squared_train_linear, 3))
print('mean_squared_error_train:', round(mean_squared_error_train_linear, 3))

# Printing results for testing
print('r_squared_test:',round(r_squared_test_linear, 3))
print('mean_squared_error_test:',round(mean_squared_error_test_linear, 3))
# Out:
# r_squared_train: 0.878
# mean_squared_error_train: 158.298
# r_squared_test: 0.344
# mean_squared_error_test: 64.846

# %% [markdown]
# The R2 for the test dataset suspicously went up just a little bit. I am going to remove the next most important feature next to see when the model breaks: 'Loan Amount ($thou)'.

# %%
# Try again without "Year" data because it seems too strongly correlated and we are trying to do this based on climate data...
test = data[data['Year'] == 2019].copy()
train = data[data['Year'] != 2019].copy()
y_test = test['Purchase Price ($thou)'].copy()
y_train = train['Purchase Price ($thou)'].copy()
X_train = train.drop(columns=['Year', 'Loan-to-Price Ratio (%)', 'Loan Amount ($thou)', 'RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()
X_test = test.drop(columns=['Year', 'RegionName', 'Loan-to-Price Ratio (%)', 'Loan Amount ($thou)', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()

# %%
# your code here
l_model = LinearRegression()
l_model.fit(X_train, y_train)
y_pred_test = l_model.predict(X_test)
y_pred_train = l_model.predict(X_train)

r_squared_train_linear = r2_score(y_train, y_pred_train)
r_squared_test_linear = r2_score(y_test, y_pred_test)

mean_squared_error_train_linear = mean_squared_error(y_train, y_pred_train)
mean_squared_error_test_linear = mean_squared_error(y_test, y_pred_test)

# Printing results for training
print('r_squared_train:', round(r_squared_train_linear, 3))
print('mean_squared_error_train:', round(mean_squared_error_train_linear, 3))

# Printing results for testing
print('r_squared_test:',round(r_squared_test_linear, 3))
print('mean_squared_error_test:',round(mean_squared_error_test_linear, 3))
# Out:
# r_squared_train: 0.447
# mean_squared_error_train: 718.749
# r_squared_test: -20.208
# mean_squared_error_test: 2097.938

# %% [markdown]
# Clearly, removing features that are related to TIME or related to HOUSING breaks the model -- which kind of indicates that attempting to predict housing purchase prices based solely on geographical and climate data is WORSE than random!
#
# **This likely means we need to go back to the drawing board.**
#
# To be certain, I will try a higher degree polynomial below.
#
# ## Polynomial Features
# First, I am resetting the test and train datasets back to have the most informatio possible.

# %%
test = data[data['Year'] == 2019].copy()
train = data[data['Year'] != 2019].copy()
y_test = test['Purchase Price ($thou)'].copy()
y_train = train['Purchase Price ($thou)'].copy()
X_train = train.drop(columns=['RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()
X_test = test.drop(columns=['RegionName', 'State', 'StateAbbrv', 'Purchase Price ($thou)', \
                       'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',\
                       'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT','geometry']).copy()

# %%
# y_poly_preds = []
# for x in range(1,5):
#     X_poly = PolynomialFeatures(degree=x)
#     X_polynomial_train = X_poly.fit_transform(X_train)
#     X_polynomial_test = X_poly.fit_transform(X_test)
#     model_poly = LinearRegression()
#     model_poly.fit(X_polynomial_train, y_train)

#     y_pred_poly_test = model_poly.predict(X_polynomial_test)
#     y_pred_poly_train = model_poly.predict(X_polynomial_train)
#     y_poly_preds.append(y_pred_poly_test)

#     r_squared_train_poly = model_poly.score(X_polynomial_train, y_train)
#     r_squared_test_poly = model_poly.score(X_polynomial_test, y_test)

#     mean_squared_error_train_poly = mean_squared_error(y_train, y_pred_poly_train)
#     mean_squared_error_test_poly = mean_squared_error(y_test, y_pred_poly_test)

#     # Printing results for training
#     print('----------------------------')
#     print("Degree: ", x)
#     print('r_squared_train:', r_squared_train_poly)
#     print('mean_squared_error_train:', mean_squared_error_train_poly)

#     # Printing results for testing
#     print('r_squared_test:',r_squared_test_poly)
#     print('mean_squared_error_test:',mean_squared_error_test_poly)
#     print('----------------------------')
#     print("")

# %% [markdown]
# Below, I have pasted an image of the output produced by this code. Above, the code is commented out, because it fails due to memory allocation. This makes sense because the dataset is currently 2.7 million rows, and attempting to fit higher-order polynomials simply requries more memory than can be allocated by my computer. The result:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Closing Thoughts
#
# The data so far indicates that we may need to change either our questions or our entire dataset. Our hypothesis that temperature change can be used to predict purchase price is "No, that in fact is worse than random."
